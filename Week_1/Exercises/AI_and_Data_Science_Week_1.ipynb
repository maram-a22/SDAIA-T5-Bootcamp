# %% [markdown]
# **Overview on Dataset**

# %%
import pandas as pd 
import numpy as np

# %%
dataset = pd.read_csv('Traffic.csv')

# %%
dataset.shape
# Out:
# (5952, 9)

# %%
dataset.head(10)
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
# 5   1:15:00 AM    10         Tuesday        15          1         1
# 6   1:30:00 AM    10         Tuesday        14          2         2
# 7   1:45:00 AM    10         Tuesday        13          2         1
# 8   2:00:00 AM    10         Tuesday         7          0         0
# 9   2:15:00 AM    10         Tuesday        13          0         0
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# ...

# %%
dataset.tail()
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 5947  10:45:00 PM     9        Thursday        16          3         1
# 5948  11:00:00 PM     9        Thursday        11          0         1
# 5949  11:15:00 PM     9        Thursday        15          4         1
# 5950  11:30:00 PM     9        Thursday        16          5         0
# 5951  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 5947          36     56            normal
# 5948          30     42            normal
# 5949          25     45            normal
# 5950          27     48            normal
# 5951          15     33               low

# %%
dataset.sample()
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 4082  12:30:00 PM    21          Sunday        31          6         8
#
#       TruckCount  Total Traffic Situation
# 4082          23     68            normal

# %% [markdown]
# **Get DataFrame information**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5952 entries, 0 to 5951
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               5952 non-null   object
#  1   Date               5952 non-null   int64
#  2   Day of the week    5952 non-null   object
#  3   CarCount           5952 non-null   int64
#  4   BikeCount          5952 non-null   int64
#  5   BusCount           5952 non-null   int64
#  6   TruckCount         5952 non-null   int64
#  7   Total              5952 non-null   int64
#  8   Traffic Situation  5952 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 418.6+ KB

# %% [markdown]
# **Get summary of the statistical properties of the numerical columns in a DataFrame**

# %%
dataset.describe()
# Out:
#               Date     CarCount    BikeCount     BusCount   TruckCount  \
# count  5952.000000  5952.000000  5952.000000  5952.000000  5952.000000
# mean     16.000000    65.440692    12.161458    12.912970    18.646337
# std       8.945023    44.749335    11.537944    12.497736    10.973139
# min       1.000000     5.000000     0.000000     0.000000     0.000000
# 25%       8.000000    18.750000     3.000000     2.000000    10.000000
# 50%      16.000000    62.000000     9.000000    10.000000    18.000000
# 75%      24.000000   103.000000    19.000000    20.000000    27.000000
# max      31.000000   180.000000    70.000000    50.000000    60.000000
#
#              Total
# count  5952.000000
# mean    109.161458
# std      55.996312
# min      21.000000
# 25%      54.000000
# 50%     104.000000
# 75%     153.000000
# max     279.000000

# %% [markdown]
# **Further analysis**

# %% [markdown]
# Count each value in the DataFrame

# %%
dataset['CarCount'].value_counts()
# Out:
# CarCount
# 15     156
# 11     145
# 14     140
# 13     134
# 12     130
#       ...
# 160      1
# 178      1
# 170      1
# 159      1
# 163      1
# Name: count, Length: 173, dtype: int64

# %%
dataset['Day of the week'].value_counts()
# Out:
# Day of the week
# Tuesday      960
# Wednesday    960
# Thursday     960
# Friday       768
# Saturday     768
# Sunday       768
# Monday       768
# Name: count, dtype: int64

# %% [markdown]
# **Checking null values**

# %%
dataset.isnull()
# Out:
#        Time   Date  Day of the week  CarCount  BikeCount  BusCount  \
# 0     False  False            False     False      False     False
# 1     False  False            False     False      False     False
# 2     False  False            False     False      False     False
# 3     False  False            False     False      False     False
# 4     False  False            False     False      False     False
# ...     ...    ...              ...       ...        ...       ...
# 5947  False  False            False     False      False     False
# 5948  False  False            False     False      False     False
# 5949  False  False            False     False      False     False
# 5950  False  False            False     False      False     False
# 5951  False  False            False     False      False     False
#
#       TruckCount  Total  Traffic Situation
# 0          False  False              False
# 1          False  False              False
# ...

# %%
dataset.isnull().sum()
# Out:
# Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %% [markdown]
# **Check how many duplicates in the DataFrame**

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5947    False
# 5948    False
# 5949    False
# 5950    False
# 5951    False
# Length: 5952, dtype: bool

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Accessing Column Data**
#
# To access data from a single column, you use the column's label.

# %%
dataset['Traffic Situation']
# Out:
# 0       normal
# 1       normal
# 2       normal
# 3       normal
# 4       normal
#          ...
# 5947    normal
# 5948    normal
# 5949    normal
# 5950    normal
# 5951       low
# Name: Traffic Situation, Length: 5952, dtype: object

# %%
dataset['Total']
# Out:
# 0       41
# 1       52
# 2       46
# 3       50
# 4       48
#         ..
# 5947    56
# 5948    42
# 5949    45
# 5950    48
# 5951    33
# Name: Total, Length: 5952, dtype: int64

# %% [markdown]
# **Selecting Multiple Columns**
#
# You can select multiple columns from a DataFrame by passing a list of column names.

# %%
dataset[['Date','Day of the week','BusCount']]
# Out:
#       Date Day of the week  BusCount
# 0       10         Tuesday         2
# 1       10         Tuesday         1
# 2       10         Tuesday         2
# 3       10         Tuesday         2
# 4       10         Tuesday         1
# ...    ...             ...       ...
# 5947     9        Thursday         1
# 5948     9        Thursday         1
# 5949     9        Thursday         1
# 5950     9        Thursday         0
# 5951     9        Thursday         1
#
# [5952 rows x 3 columns]

# %% [markdown]
# **Using iloc for Index-Based Selection**
#
# The iloc method is used for index-based selection, allowing us to select rows and columns by their integer index.

# %%
dataset.iloc[78]
# Out:
# Time                 7:30:00 PM
# Date                         10
# Day of the week         Tuesday
# CarCount                     98
# BikeCount                     5
# BusCount                      7
# TruckCount                   30
# Total                       140
# Traffic Situation        normal
# Name: 78, dtype: object

# %%
dataset.iloc[55:59]
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 55  1:45:00 PM    10         Tuesday        63         11        16
# 56  2:00:00 PM    10         Tuesday         7         17        20
# 57  2:15:00 PM    10         Tuesday        76         15        32
# 58  2:30:00 PM    10         Tuesday        59         14        18
#
#     TruckCount  Total Traffic Situation
# 55          11    101            normal
# 56          18     62            normal
# 57          17    140              high
# 58          28    119            normal

# %% [markdown]
# **Using loc for Label-Based Selection**
#
# The loc method allows for label-based selection. This example demonstrates selecting data by multi-index labels.

# %%
dataset.loc[55:59 , ['Date','Day of the week','BusCount']]
# Out:
#     Date Day of the week  BusCount
# 55    10         Tuesday        16
# 56    10         Tuesday        20
# 57    10         Tuesday        32
# 58    10         Tuesday        18
# 59    10         Tuesday         3

# %%
dataset = dataset.set_index(['Day of the week','Time'])
dataset.loc[('Sunday', '12:15:00 AM')]
# Out:
# /var/folders/8w/pd5cnwsd4616sv8_6d54k0gr0000gn/T/ipykernel_3107/1676052192.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   dataset.loc[('Sunday', '12:15:00 AM')]
#                              Date  CarCount  BikeCount  BusCount  TruckCount  \
# Day of the week Time
# Sunday          12:15:00 AM    15         7          2         0          24
#                 12:15:00 AM    22         8          1         1          27
#                 12:15:00 AM    29         5          2         1          21
#                 12:15:00 AM     5        15          0         2          29
#                 12:15:00 AM    15        19          3         0          38
#                 12:15:00 AM    21        17          4         1          24
#                 12:15:00 AM    29        14          2         1          26
#                 12:15:00 AM     5        11          5         0          14
#
#                              Total Traffic Situation
# ...

# %% [markdown]
# **Resetting Index**
#
# Resetting the index of a DataFrame can simplify data handling, especially after operations that may create a hierarchical index.

# %%
dataset = dataset.reset_index()

# %%
dataset.head()
# Out:
#   Day of the week         Time  Date  CarCount  BikeCount  BusCount  \
# 0         Tuesday  12:00:00 AM    10        13          2         2
# 1         Tuesday  12:15:00 AM    10        14          1         1
# 2         Tuesday  12:30:00 AM    10        10          2         2
# 3         Tuesday  12:45:00 AM    10        10          2         2
# 4         Tuesday   1:00:00 AM    10        11          2         1
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %% [markdown]
# **Conditional Selection Using loc**
#
# We can perform conditional selection using loc to select rows based on a specific condition.

# %%
dataset[dataset['Total'] > 260]
# Out:
#      Day of the week         Time  Date  CarCount  BikeCount  BusCount  \
# 3307          Friday  10:45:00 AM    13       178         68        28
# 3308          Friday  11:00:00 AM    13       169         70        20
# 3315          Friday  12:45:00 PM    13       174         67        30
# 4646          Friday   9:30:00 AM    27       180         69        29
# 4650          Friday  10:30:00 AM    27       180         62        26
# 5319          Friday   9:45:00 AM     3       168         68        27
#
#       TruckCount  Total Traffic Situation
# 3307           4    278             heavy
# 3308           3    262             heavy
# 3315           1    272             heavy
# 4646           1    279             heavy
# 4650           4    272             heavy
# 5319           2    265             heavy

# %% [markdown]
# **Conditional Selection Using query**
#
# The query method allows for filtering data using a condition, similar to the conditional selection but often more readable and concise.

# %%
dataset.query('Total > 260')
# Out:
#      Day of the week         Time  Date  CarCount  BikeCount  BusCount  \
# 3307          Friday  10:45:00 AM    13       178         68        28
# 3308          Friday  11:00:00 AM    13       169         70        20
# 3315          Friday  12:45:00 PM    13       174         67        30
# 4646          Friday   9:30:00 AM    27       180         69        29
# 4650          Friday  10:30:00 AM    27       180         62        26
# 5319          Friday   9:45:00 AM     3       168         68        27
#
#       TruckCount  Total Traffic Situation
# 3307           4    278             heavy
# 3308           3    262             heavy
# 3315           1    272             heavy
# 4646           1    279             heavy
# 4650           4    272             heavy
# 5319           2    265             heavy

# %%
import pandas as pd
import numpy as np

# %%
# Create dataframes for examples
left_dataframe = pd.DataFrame({"ID": [1,2,3,4], "left_side": "LEFT"})
right_dataframe = pd.DataFrame({"ID": [3,4,5,6], "right_side": "RIGHT"})

# %%
pd.merge(left_dataframe,right_dataframe , on='ID', how = 'left')
# Out:
#    ID left_side right_side
# 0   1      LEFT        NaN
# 1   2      LEFT        NaN
# 2   3      LEFT      RIGHT
# 3   4      LEFT      RIGHT

# %%
pd.merge(left_dataframe,right_dataframe, on='ID',how='right')
# Out:
#    ID left_side right_side
# 0   3      LEFT      RIGHT
# 1   4      LEFT      RIGHT
# 2   5       NaN      RIGHT
# 3   6       NaN      RIGHT

# %%
pd.merge(left_dataframe,right_dataframe, on='ID',how='inner')
# Out:
#    ID left_side right_side
# 0   3      LEFT      RIGHT
# 1   4      LEFT      RIGHT

# %%
pd.merge(left_dataframe,right_dataframe, on='ID',how='outer')
# Out:
#    ID left_side right_side
# 0   1      LEFT        NaN
# 1   2      LEFT        NaN
# 2   3      LEFT      RIGHT
# 3   4      LEFT      RIGHT
# 4   5       NaN      RIGHT
# 5   6       NaN      RIGHT

# %% [markdown]
# **Example**
#
# In these examples, we're merging actual restaurant ratings with parking lot info. I've highlighted the placeID columns because that's what we are merging on. You might want to fork this kernel and explore the final dataframes to see the differences when using the different merge methods.

# %%
# Load restaurant ratings and parking data into dataframes
ratings = pd.read_csv("rating_final.csv")
parking = pd.read_csv("chefmozparking.csv")

# %%
# Left merge: Keep everything from the left, drop things from the right (if they don't match)
df = pd.merge(ratings, parking, on='placeID', how = 'left')
df.head(10)
# Out:
#   userID  placeID  rating  food_rating  service_rating parking_lot
# 0  U1077   135085       2            2               2      public
# 1  U1077   135038       2            2               1        none
# 2  U1077   132825       2            2               2        none
# 3  U1077   135060       1            2               2        none
# 4  U1068   135104       1            1               2         yes
# 5  U1068   132740       0            0               0        none
# 6  U1068   132663       1            1               1        none
# 7  U1068   132732       0            0               0        none
# 8  U1068   132630       1            1               1        none
# 9  U1067   132584       2            2               2         yes

# %% [markdown]
# **Grouping Data**
#
# Here, we demonstrate how to group data by a single category (Day of the week) and sum the Total column for each group.

# %%
dataset_groubed = dataset.groupby(['Day of the week'])['Total'].sum() 
print(dataset_groubed)
# Out:
# Day of the week
# Friday        81626
# Monday        83576
# Saturday      84542
# Sunday        84201
# Thursday     105074
# Tuesday      104882
# Wednesday    105828
# Name: Total, dtype: int64

# %% [markdown]
# **Multiple Grouping**
#
# This example shows how to group by multiple categories (Day of the week and Date) and aggregate the Total traffic count.

# %%
dataset_g = dataset.groupby(['Date', 'Traffic Situation'])['Total'].sum()
print(dataset_g)
# Out:
# Date  Traffic Situation
# 1     heavy                 7651
#       high                  1729
#       low                   1362
#       normal               10417
# 2     heavy                 6503
#                            ...
# 30    normal               10907
# 31    heavy                 6534
#       high                  1509
#       low                   1897
#       normal               11266
# Name: Total, Length: 124, dtype: int64

# %% [markdown]
# **Aggregation**
#
# ***Aggregation Introduction***
#
# Aggregation is a powerful way to perform calculations on grouped data. This includes operations like sum, mean, max, and min.

# %%
dataset['CarCount'].sum()
# Out:
# 389503

# %%
dataset['BikeCount'].count()
# Out:
# 5952

# %%
dataset['TruckCount'].mean()
# Out:
# 18.646337365591396

# %%
dataset['Total'].max()
# Out:
# 279

# %%
dataset['BusCount'].min()
# Out:
# 0

# %% [markdown]
# **Grouping with Aggregation**
#
# ***Advanced Grouping with Aggregation***
#
# This cell demonstrates the use of agg() to apply multiple aggregation functions to different columns in a grouped DataFrame.

# %%
dataset = dataset.groupby(['Day of the week']).agg(
    Total_Cars = ('BusCount', 'sum'),
    Average_Cars = ('BusCount', 'mean'),
    Maximum_Cars = ('BusCount', 'max'),
    Minimum_Cars = ('BusCount', 'min'),
    Count = ('BusCount', 'count')
)

dataset
# Out:
#                  Total_Cars  Average_Cars  Maximum_Cars  Minimum_Cars  Count
# Day of the week
# Friday                 5297      6.897135            30             0    768
# Monday                10652     13.869792            50             0    768
# Saturday              10508     13.682292            50             0    768
# Sunday                10612     13.817708            50             0    768
# Thursday              13460     14.020833            50             0    960
# Tuesday               13106     13.652083            50             0    960
# Wednesday             13223     13.773958            50             0    960

# %%
dataset = dataset.groupby(['Day of the week', 'BikeCount']).agg(
    Total_Cars = ('BusCount', 'sum'),
    Average_Cars = ('BusCount', 'mean'),
    Maximum_Cars = ('BusCount', 'max'),
    Minimum_Cars = ('BusCount', 'min'),
    Count = ('BusCount', 'count')
)

dataset
# Out:
#                            Total_Cars  Average_Cars  Maximum_Cars  \
# Day of the week BikeCount
# Friday          0                  70      1.129032             5
#                 1                 112      1.577465             7
#                 2                 113      1.547945             7
#                 3                  50      1.724138             6
#                 4                  47      1.382353             5
# ...                               ...           ...           ...
# Wednesday       36                 41     41.000000            41
#                 37                164     41.000000            48
#                 38                107     35.666667            50
#                 39                222     37.000000            49
#                 40                175     29.166667            36
#
#                            Minimum_Cars  Count
# Day of the week BikeCount
# Friday          0                     0     62
# ...

# %%
dataset = dataset.groupby(['Day of the week', 'Traffic Situation']).agg(
    Total_Cars = ('Total', 'sum'),
    Average_Cars = ('Total', 'mean'),
    Maximum_Cars = ('Total', 'max'),
    Minimum_Cars = ('Total', 'min'),
    Count = ('Total', 'count')
)

dataset
# Out:
#                                    Total_Cars  Average_Cars  Maximum_Cars  \
# Day of the week Traffic Situation
# Friday          heavy                   35466    214.945455           279
#                 high                     4087    123.848485           142
#                 low                     15732     69.920000           111
#                 normal                  26341     76.350725           167
# Monday          heavy                   27581    190.213793           226
#                 high                     6824    139.265306           166
#                 low                      6566     69.851064           111
#                 normal                  42605     88.760417           167
# Saturday        heavy                   28722    191.480000           237
#                 high                     5136    138.810811           165
#                 low                      6286     66.872340           167
# ...

# %%
ds = pd.read_csv('Titanic-Dataset.csv')

# %%
ds.shape
# Out:
# (891, 12)

# %%
ds.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ds['Age'].isna().sum()
# Out:
# 177

# %%
ds['Cabin'].isna().sum()
# Out:
# 687

# %%
ds['Embarked'].isna().sum()
# Out:
# 2

# %%
ds['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
ds['Embarked'].fillna(method = 'ffill', limit = 1 , inplace= True )
print(ds.isna().sum())
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            19
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# Fare_1          0
# dtype: int64
# /var/folders/8w/pd5cnwsd4616sv8_6d54k0gr0000gn/T/ipykernel_3107/193640783.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ds['Embarked'].fillna(method = 'ffill', limit = 1 , inplace= True )
# ...

# %%
ds = ds.drop('Embarked_after_fill', axis = 1)

# %%
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds.dropna(subset=['Cabin'], inplace=True)

# %%
ds['Cabin'].isnull().sum()
# Out:
# 0

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
ds.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
import numpy as np

# %%
sns.boxplot(ds['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
# Function to remove outliers using the IQR method
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
ds_out =  remove_outliers(ds , 'Fare')

# %%
sns.boxplot(ds_out['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
Scaler_1 = StandardScaler()

ds['Fare_1'] = Scaler_1.fit_transform(ds[['Fare']])
print(ds['Fare_1'])
# Out:
# 1     -0.065466
# 3     -0.310494
# 6     -0.327170
# 10    -0.800999
# 11    -0.668266
#          ...
# 871   -0.317849
# 872   -0.958662
# 879    0.094554
# 887   -0.621776
# 889   -0.621776
# Name: Fare_1, Length: 204, dtype: float64

# %%
Scaler_2 = MinMaxScaler()

ds['Age'] = Scaler_2.fit_transform(ds[['Age']])
print(ds['Age'])
# Out:
# 1      0.468892
# 3      0.430956
# 6      0.671219
# 10     0.038948
# 11     0.721801
#          ...
# 871    0.582701
# 872    0.405665
# 879    0.696510
# 887    0.228629
# 889    0.317147
# Name: Age, Length: 204, dtype: float64

# %% [markdown]
# **Encoding Categorical Variables**

# %%
print(ds['Embarked'].unique())
# Out:
# ['C' 'S' 'Q']

# %%
print(ds['Sex'].unique())
# Out:
# ['female' 'male']

# %%
OHE = pd.get_dummies(ds['Embarked'])
print(OHE)
# Out:
#          C      Q      S
# 1     True  False  False
# 3    False  False   True
# 6    False  False   True
# 10   False  False   True
# 11   False  False   True
# ..     ...    ...    ...
# 871  False  False   True
# 872  False  False   True
# 879   True  False  False
# 887  False  False   True
# 889   True  False  False
#
# [204 rows x 3 columns]

# %%
ds = pd.get_dummies(ds, columns=['Embarked'])
ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0      0         A/5 21171   7.2500   NaN       False       False        True
# 1      0          PC 17599  71.2833   C85        True       False       False
# 2      0  STON/O2. 3101282   7.9250   NaN       False       False        True
# ...

# %%
ds = pd.get_dummies(ds, columns=['Embarked' , "Sex"])
ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S  \
# 0         A/5 21171   7.2500   NaN       False       False        True
# 1          PC 17599  71.2833   C85        True       False       False
# 2  STON/O2. 3101282   7.9250   NaN       False       False        True
# ...

# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder 

label_encoder = LabelEncoder()

ds['Embarked_after'] = label_encoder.fit_transform(ds['Embarked'])

# %%
ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Embarked_after
# 0      0         A/5 21171   7.2500   NaN        S               2
# 1      0          PC 17599  71.2833   C85        C               0
# 2      0  STON/O2. 3101282   7.9250   NaN        S               2
# ...

# %%
maping = {"S":1, "C":2, "Q":3}

ds['Embarked'] = ds['Embarked'].map(maping)

ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked  Embarked_after
# 0      0         A/5 21171   7.2500   NaN       1.0               2
# 1      0          PC 17599  71.2833   C85       2.0               0
# 2      0  STON/O2. 3101282   7.9250   NaN       1.0               2
# ...

# %%
DS = sns.load_dataset('car_crashes')
DS.head(10)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
# 7   16.2     6.156    4.860          14.094       16.038      1137.87
# 8    5.9     2.006    1.593           5.900        5.900      1273.89
# 9   17.9     3.759    5.191          16.468       16.826      1160.13
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
# 5      139.91     CO
# 6      167.02     CT
# ...

# %%
DS.shape
# Out:
# (51, 8)

# %%
DS.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
DS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
DS.isna().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
DS.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(DS['alcohol'])
# Out:
# <Axes: ylabel='alcohol'>

# %%
# Function to remove outliers using the IQR method
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
DS_out = remove_outliers(DS ,'alcohol')

# %%
sns.boxplot(DS_out['alcohol'])
# Out:
# <Axes: ylabel='alcohol'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10, 5))
sns.histplot(DS['total'], kde = True, bins = 20, color= 'red')
plt.title('Histogram of Total Crashes')
plt.xlabel('Total Crashes')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar Chart for average insurance premium by state
plt.figure(figsize=(10, 6))
sns.barplot(DS, x='abbrev', y='ins_premium', palette='muted')
plt.title('Average Insurance Premium by State')
plt.xlabel('State')
plt.ylabel('Average Insurance Premium')
plt.xticks(rotation=90)# for the label button the chart how its show 
plt.show()
# Out:
# /var/folders/8w/pd5cnwsd4616sv8_6d54k0gr0000gn/T/ipykernel_3107/3122989533.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(DS, x='abbrev', y='ins_premium', palette='muted')

# %%
# Create scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(DS, x='speeding', y='alcohol', hue='abbrev')

# Adjust the plot
plt.show()

# %%
DS.plot.hexbin( x='speeding', y= 'alcohol', gridsize = 15)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
DS['total'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='total'>

# %%
DS.head().groupby(['abbrev']).sum().plot(kind='pie', y='total', autopct='%1.0f%%')
# Out:
# <Axes: ylabel='total'>

# %%
DS[DS['total'] > 15 ]['total'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
(DS[].value_counts().head(10)/len(DS)).plot.bar()

# %%
DS.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
columns = DS[['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous','ins_premium', 'ins_losses']]

# %%
cc = columns.corr()

# %%
# plotting correlation heatmap 
sns.heatmap(columns.corr(), annot=True) 
# displaying heatmap 
plt.show()

# %%
sns.pairplot(cc)
# to show
plt.show()

# %%
sns.violinplot(DS.head(), x='abbrev' , y= 'total')
# Out:
# <Axes: xlabel='abbrev', ylabel='total'>
