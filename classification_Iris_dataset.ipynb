# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# show plot in the notebook
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.inspection import DecisionBoundaryDisplay

# %%
ds = pd.read_csv('Iris.csv')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
ds
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
ds.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
ds['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
X = ds.drop(['Species', 'Id'], axis=1)
y = ds['Species']
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2, shuffle=True,random_state= 0)

# %%
X.shape
# Out:
# (150, 4)

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y.shape
# Out:
# (150,)

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
y_test
# Out:
# 114     Iris-virginica
# 62     Iris-versicolor
# 33         Iris-setosa
# 107     Iris-virginica
# 7          Iris-setosa
# 100     Iris-virginica
# 40         Iris-setosa
# 86     Iris-versicolor
# 76     Iris-versicolor
# 71     Iris-versicolor
# 134     Iris-virginica
# 51     Iris-versicolor
# 73     Iris-versicolor
# 54     Iris-versicolor
# 63     Iris-versicolor
# 37         Iris-setosa
# 78     Iris-versicolor
# 90     Iris-versicolor
# 45         Iris-setosa
# 16         Iris-setosa
# 121     Iris-virginica
# 66     Iris-versicolor
# 24         Iris-setosa
# 8          Iris-setosa
# 126     Iris-virginica
# 22         Iris-setosa
# 44         Iris-setosa
# 97     Iris-versicolor
# 93     Iris-versicolor
# 26         Iris-setosa
# Name: Species, dtype: object

# %%
result = accuracy_score(y_pred,y_test)*100
print('the model accuracy is:',result,'%')
# Out:
# the model accuracy is: 100.0 %

# %%
predict = model.predict(X_test)
# compare test and train data
compar = pd.DataFrame({'actual': y_test, 'predicted': predict})
compar = compar.reset_index(drop = True)
compar[:15]
# Out:
#              actual        predicted
# 0    Iris-virginica   Iris-virginica
# 1   Iris-versicolor  Iris-versicolor
# 2       Iris-setosa      Iris-setosa
# 3    Iris-virginica   Iris-virginica
# 4       Iris-setosa      Iris-setosa
# 5    Iris-virginica   Iris-virginica
# 6       Iris-setosa      Iris-setosa
# 7   Iris-versicolor  Iris-versicolor
# 8   Iris-versicolor  Iris-versicolor
# 9   Iris-versicolor  Iris-versicolor
# 10   Iris-virginica   Iris-virginica
# 11  Iris-versicolor  Iris-versicolor
# 12  Iris-versicolor  Iris-versicolor
# 13  Iris-versicolor  Iris-versicolor
# 14  Iris-versicolor  Iris-versicolor

# %%
_, ax = plt.subplots(figsize=(4, 3))
DecisionBoundaryDisplay.from_estimator(
    model,
    X,
    cmap=plt.cm.Paired,
    ax=ax,
    response_method="predict",
    plot_method="pcolormesh",
    shading="auto",
    xlabel="Sepal length",
    ylabel="Sepal width",
    eps=0.5,
)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors="k", cmap=plt.cm.Paired)


plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[209], line 2
#       1 _, ax = plt.subplots(figsize=(4, 3))
# ----> 2 DecisionBoundaryDisplay.from_estimator(
#       3     model,
#       4     X,
#       5     cmap=plt.cm.Paired,
#       6     ax=ax,
#       7     response_method="predict",
#       8     plot_method="pcolormesh",
#       9     shading="auto",
#      10     xlabel="Sepal length",
#      11     ylabel="Sepal width",
#      12     eps=0.5,
#      13 )
#      15 # Plot also the training points
#      16 plt.scatter(X, X, c=Y, edgecolors="k", cmap=plt.cm.Paired)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/inspection/_plot/decision_boundary.py:334, in DecisionBoundaryDisplay.from_estimator(cls, estimator, X, grid_resolution, eps, plot_method, response_method, class_of_interest, xlabel, ylabel, ax, **kwargs)
#     332 num_features = _num_features(X)
#     333 if num_features != 2:
# --> 334     raise ValueError(
#     335         f"n_features must be equal to 2. Got {num_features} instead."
#     336     )
#     338 x0, x1 = _safe_indexing(X, 0, axis=1), _safe_indexing(X, 1, axis=1)
#     340 x0_min, x0_max = x0.min() - eps, x0.max() + eps
#
# ValueError: n_features must be equal to 2. Got 4 instead.
