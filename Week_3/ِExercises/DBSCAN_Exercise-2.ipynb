# %% [markdown]
# #**DBSCAN**

# %% [markdown]
# #Step 1 : Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn import datasets

# %% [markdown]
# #Step 2 : Prepare dataset
# ###**use make blobs with different numbers**

# %%
# Load data in X
X, y_true = make_blobs(n_samples=600, centers=5,cluster_std=0.40, random_state=32)

# %% [markdown]
# #Step 3 : Modeling The Data Using DBSCAN

# %%
db = DBSCAN(eps=0.5, min_samples=10).fit(X) # eps to small so some data being as outlires , min_samples == num of neighbours 
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

# Plot result

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = ['y', 'b', 'g', 'r']
print(colors)
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k',
             markersize=6)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k',
             markersize=6)

plt.title('number of clusters: %d' % n_clusters_)
plt.show()
# the plot do stander scaler so the size is small
# Out:
# ['y', 'b', 'g', 'r']

# %% [markdown]
# #Step 4 : Evaluation Metrics For DBSCAN Algorithm In Machine Learning

# %%
# evaluation metrics
from sklearn import metrics
sc = metrics.silhouette_score(X, labels)
print("Silhouette Coefficient:%0.2f" % sc)
ari = metrics.adjusted_rand_score(y_true, labels) 
print("Adjusted Rand Index: %0.2f" % ari)
# Out:
# Silhouette Coefficient:0.87
# Adjusted Rand Index: 0.99

# %% [markdown]
# #**Well Done :)**
