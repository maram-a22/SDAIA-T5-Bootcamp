# %% [markdown]
# #Dataset Description

# %% [markdown]
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset = pd.read_csv('Task (1) Dataset.csv')

# %%
dataset.shape
# Out:
# (12316, 32)

# %% [markdown]
# **info()summery and semmurize the dataset**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
# Show frist 5 row or you can determined by aurgment 
dataset.head(10)
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
# 5  14:15:00      Friday              31-50          Male                 NaN
# 6  17:30:00   Wednesday              18-30          Male  Junior high school
# 7  17:20:00      Friday              18-30          Male  Junior high school
# 8  17:20:00      Friday              18-30          Male  Junior high school
# 9  17:20:00      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# ...

# %%
# Show last 5 row or you can determined by aurgment 
dataset.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
# Show random rows and each run is diffrenet 
dataset.sample()
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 11663  5:49:00     Tuesday              18-30          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 11663  Elementary school                Employee             5-10yr
#
#       Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 11663           Other            Owner                 5-10yrs  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 11663  Moving Backward  Driver or rider            Male                18-30
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 11663                 2     Self-employed               Normal
#
#       Pedestrian_movement          Cause_of_accident Accident_severity
# 11663    Not a Pedestrian  No priority to pedestrian     Slight Injury
#
# [1 rows x 32 columns]

# %% [markdown]
# **understaned the relationship between numerical varibles in the dataset**

# %%
columns = dataset[['Number_of_vehicles_involved','Number_of_casualties']]

columns.corr()
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %% [markdown]
# **set_index() help us in faster search and data combinations**

# %%
dataset.set_index(['Age_band_of_driver','Sex_of_driver'], inplace=True )
dataset.loc[('18-30','Female')]
# Out:
# /var/folders/8w/pd5cnwsd4616sv8_6d54k0gr0000gn/T/ipykernel_8120/74648466.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   dataset.loc[('18-30','Female')]
#                                       Time Day_of_week   Educational_level  \
# Age_band_of_driver Sex_of_driver
# 18-30              Female         22:45:00      Monday  Junior high school
#                    Female         11:19:00      Monday         High school
#                    Female         20:55:00      Friday   Elementary school
#                    Female         12:55:00      Monday  Junior high school
#                    Female         23:45:00      Friday  Junior high school
#                    Female         19:47:00    Saturday  Junior high school
#                    Female          7:35:00    Thursday   Elementary school
#                    Female          9:09:00      Monday  Junior high school
#                    Female         17:15:00     Tuesday  Junior high school
# ...

# %%
dataset.set_index(['Age_band_of_driver','Sex_of_driver'], inplace=True )
dataset.loc[('18-30','Male')]
# Out:
# /var/folders/8w/pd5cnwsd4616sv8_6d54k0gr0000gn/T/ipykernel_8120/3390700354.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   dataset.loc[('18-30','Male')]
#                                       Time Day_of_week   Educational_level  \
# Age_band_of_driver Sex_of_driver
# 18-30              Male           17:02:00      Monday   Above high school
#                    Male           17:02:00      Monday  Junior high school
#                    Male            1:06:00      Sunday  Junior high school
#                    Male            1:06:00      Sunday  Junior high school
#                    Male           17:30:00   Wednesday  Junior high school
# ...                                    ...         ...                 ...
#                    Male            7:10:00      Friday  Junior high school
#                    Male           17:10:00      Friday  Junior high school
#                    Male           17:10:00      Friday  Junior high school
# ...

# %%
dataset.reset_index(inplace=True)
dataset.head()
# Out:
#    index Age_band_of_driver Sex_of_driver      Time Day_of_week  \
# 0      0              18-30          Male  17:02:00      Monday
# 1      1              31-50          Male  17:02:00      Monday
# 2      2              18-30          Male  17:02:00      Monday
# 3      3              18-30          Male   1:06:00      Sunday
# 4      4              18-30          Male   1:06:00      Sunday
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Vehicle_movement  \
# 0           Automobile            Owner  ...   Going straight
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
#just to see the null vale or missing value in the dataset
dataset.isnull()
# Out:
#         Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0      False        False               False          False
# 1      False        False               False          False
# 2      False        False               False          False
# 3      False        False               False          False
# 4      False        False               False          False
# ...      ...          ...                 ...            ...
# 12311  False        False               False          False
# 12312  False        False               False          False
# 12313  False        False               False          False
# 12314  False        False               False          False
# 12315  False        False               False          False
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                  False                    False               False
# 1                  False                    False               False
# ...

# %%
# to see the null value in shorter format
dataset.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
# the mode value in one column 
dataset['Educational_level'].mode()
# Out:
# 0    Junior high school
# Name: Educational_level, dtype: object

# %%
# full the null value or missing value with the mode in Educational_level column 
dataset['Educational_level'].fillna(method = 'ffill', limit = 1 , inplace= True )
# Out:
# /var/folders/8w/pd5cnwsd4616sv8_6d54k0gr0000gn/T/ipykernel_8120/2917352662.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset['Educational_level'].fillna(method = 'ffill', limit = 1 , inplace= True )

# %%
print(dataset['Educational_level'].isna().sum())
# Out:
# 0

# %%
# just to see the duplicated in dataset
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
dataset.loc[50:60 ,['Time']]
# Out:
#         Time
# 50  19:12:00
# 51  19:12:00
# 52  11:38:00
# 53  11:38:00
# 54  11:38:00
# 55  11:38:00
# 56  13:30:00
# 57  13:30:00
# 58  12:39:00
# 59  12:39:00
# 60  12:30:00

# %%
dataset = pd.to_datetime(dataset['Time'])
print(dataset.head(15))
# Out:
# 0    2024-07-25 17:02:00
# 1    2024-07-25 17:02:00
# 2    2024-07-25 17:02:00
# 3    2024-07-25 01:06:00
# 4    2024-07-25 01:06:00
# 5    2024-07-25 14:15:00
# 6    2024-07-25 17:30:00
# 7    2024-07-25 17:20:00
# 8    2024-07-25 17:20:00
# 9    2024-07-25 17:20:00
# 10   2024-07-25 14:40:00
# 11   2024-07-25 14:40:00
# 12   2024-07-25 17:45:00
# 13   2024-07-25 17:45:00
# 14   2024-07-25 17:45:00
# Name: Time, dtype: datetime64[ns]
# /var/folders/8w/pd5cnwsd4616sv8_6d54k0gr0000gn/T/ipykernel_8120/4197391117.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset = pd.to_datetime(dataset['Time'])

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
dataset.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %% [markdown]
# **describe() use to show statical summery od the dataset and just work on numerical columns**

# %%
dataset.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
dataset['Service_year_of_vehicle'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='Service_year_of_vehicle'>

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.histplot(dataset['Age_band_of_driver'], kde=True, bins=20, color='red')
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Count'>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
sns.scatterplot(dataset, x='Driving_experience', y='Weather_conditions')
# Out:
# <Axes: xlabel='Driving_experience', ylabel='Weather_conditions'>

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
dataset['Area_accident_occured'].unique()
# Out:
# array(['Residential areas', 'Office areas', '  Recreational areas',
#        ' Industrial areas', nan, 'Other', ' Church areas',
#        '  Market areas', 'Unknown', 'Rural village areas',
#        ' Outside rural areas', ' Hospital areas', 'School areas',
#        'Rural village areasOffice areas', 'Recreational areas'],
#       dtype=object)

# %%
dataset.groupby(['Area_accident_occured']).sum().plot(kind='pie', y='Number_of_casualties', autopct='%1.0f%%')
# Out:
# <Axes: ylabel='Number_of_casualties'>

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
columns = dataset[['Number_of_vehicles_involved','Number_of_casualties']]

columns.corr()
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %%
# plotting correlation heatmap 
sns.heatmap(columns.corr(), annot=True) 
# displaying heatmap 
plt.show()

# %%
columns = dataset[['Number_of_vehicles_involved','Number_of_casualties']]

sns.pairplot(columns)
# to show
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# **1- From viewing the data I discovered that male in the age of 18-30 do more traffic accidents than female, while the male(4150) traffic accidents in that group 18-30 years old and female have just (55 rows) traffic accidents recorded, I see that the Junior high school is the most Educational_level with traffic accidents, The graph show that the Service years of the vehicle increase while the age of the person increase, You can note that Office areas is more places with traffic accidents**
